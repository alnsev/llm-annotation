# %% [markdown]
# <a href="https://colab.research.google.com/github/alnsev/llm-annotation/blob/main/pipeline_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U spacy

# !python -m spacy download ru_core_news_sm
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.11/dist-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.11/dist-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (0.15.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.11/dist-packages (from spacy) (2.11.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from spacy) (75.2.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.11/dist-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in /usr/local/lib/python3.11/dist-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.1 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.1)
# Requirement already satisfied: typing-extensions>=4.12.2 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.1.31)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in /usr/local/lib/python3.11/dist-packages (from typer<1.0.0,>=0.3.0->spacy) (13.9.4)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /usr/local/lib/python3.11/dist-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->spacy) (3.0.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.18.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Collecting ru-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/ru_core_news_sm-3.8.0/ru_core_news_sm-3.8.0-py3-none-any.whl (15.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/15.3 MB 51.1 MB/s eta 0:00:00
# Collecting pymorphy3>=1.0.0 (from ru-core-news-sm==3.8.0)
#   Downloading pymorphy3-2.0.3-py3-none-any.whl.metadata (1.9 kB)
# Collecting dawg2-python>=0.8.0 (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading dawg2_python-0.9.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting pymorphy3-dicts-ru (from pymorphy3>=1.0.0->ru-core-news-sm==3.8.0)
#   Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl.metadata (2.0 kB)
# Downloading pymorphy3-2.0.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 1.9 MB/s eta 0:00:00
# Downloading dawg2_python-0.9.0-py3-none-any.whl (9.3 kB)
# Downloading pymorphy3_dicts_ru-2.4.417150.4580142-py2.py3-none-any.whl (8.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 48.5 MB/s eta 0:00:00
# Installing collected packages: pymorphy3-dicts-ru, dawg2-python, pymorphy3, ru-core-news-sm
# Successfully installed dawg2-python-0.9.0 pymorphy3-2.0.3 pymorphy3-dicts-ru-2.4.417150.4580142 ru-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('ru_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import spacy

nlp = spacy.load("ru_core_news_sm")

text = """
В тени высокой липы, на берегу Москвы-реки, недалеко от Кунцева, в один из самых жарких летних дней 1853 года лежали на траве два молодых человека. Один, на вид лет двадцати трех, высокого роста, черномазый, с острым и немного кривым носом, высоким лбом и сдержанною улыбкой на широких губах, лежал на спине и задумчиво глядел вдаль, слегка прищурив свои небольшие серые глазки; другой лежал на груди, подперев обеими руками кудрявую белокурую голову, и тоже глядел куда-то вдаль. Он был тремя годами старше своего товарища, но казался гораздо моложе; усы его едва пробились и на подбородке вился легкий пух. Было что-то детски-миловидное, что-то привлекательно изящное в мелких чертах его свежего, круглого лица, в его сладких карих глазах, красивых выпуклых губках и белых ручках. Всё в нем дышало счастливою веселостью здоровья, дышало молодостью — беспечностью, самонадеянностью, избалованностью, прелестью молодости. Он и поводил глазами, и улыбался, и подпирал голову, как это делают мальчики, которые знают, что на них охотно заглядываются. На нем было просторное белое пальто вроде блузы; голубой платок охватывал его тонкую шею, измятая соломенная шляпа валялась в траве возле него.
В сравнении с ним его товарищ казался стариком, и никто бы не подумал, глядя на его угловатую фигуру, что и он наслаждается, что и ему хорошо. Он лежал неловко; его большая, кверху широкая, книзу заостренная голова неловко сидела на длинной шее; неловкость сказывалась в самом положении его рук, его туловища, плотно охваченного коротким черным сюртучком, его длинных ног с поднятыми коленями, подобных задним ножкам стрекозы. Со всем тем нельзя было не признать в нем хорошо воспитанного человека; отпечаток «порядочности» замечался во всем его неуклюжем существе, и лицо его, некрасивое и даже несколько смешное, выражало привычку мыслить и доброту. Звали его Андреем Петровичем Берсеневым; его товарищ, белокурый молодой человек, прозывался Шубиным, Павлом Яковлевичем.
— Отчего ты не лежишь, как я, на груди? — начал Шубин. — Так гораздо лучше. Особенно когда поднимешь ноги и стучишь каблуками дружку о дружку — вот так. Трава под носом: надоест глазеть на пейзаж — смотри на какую-нибудь пузатую козявку, как она ползет по былинке, или на муравья, как он суетится. Право, так лучше. А то ты принял теперь какую-то псевдоклассическую позу, ни дать ни взять танцовщица в балете, когда она облокачивается на картонный утес. Ты вспомни, что ты теперь имеешь полное право отдыхать. Шутка сказать: вышел третьим кандидатом! Отдохните, сэр; перестаньте напрягаться, раскиньте свои члены!
Шубин произнес всю эту речь в нос, полулениво, полушутливо (балованные дети говорят так с друзьями дома, которые привозят им конфекты), и, не дождавшись ответа, продолжал:
— Меня больше всего поражает в муравьях, жуках и других господах насекомых их удивительная серьезность; бегают взад и вперед с такими важными физиономиями, точно и их жизнь что-то значит! Помилуйте, человек, царь созданья, существо высшее, на них взирает, а им и дела до него нет; еще, пожалуй, иной комар сядет на нос царю создания и станет употреблять его себе в пищу. Это обидно. А с другой стороны, чем их жизнь хуже нашей жизни? И отчего же им не важничать, если мы позволяем себе важничать? Ну-ка, философ, разреши мне эту задачу! Что ж ты молчишь? А?
— Что? — проговорил, встрепенувшись, Берсенев.
— Что! — повторил Шубин. — Твой друг излагает перед тобою глубокие мысли, а ты его не слушаешь.
— Я любовался видом. Посмотри, как эти поля горячо блестят на солнце! (Берсенев немного пришепетывал.)
— Важный пущен колер, — промолвил Шубин. — Одно слово, натура!
Берсенев покачал головой.
— Тебе бы еще больше меня следовало восхищаться всем этим. Это по твоей части: ты артист.
— Нет-с; это не по моей части-с, — возразил Шубин и надел шляпу на затылок. — Я мясник-с; мое дело — мясо, мясо лепить, плечи, ноги, руки, а тут и формы нет, законченности нет, разъехалось во все стороны... Пойди поймай!
— Да ведь и тут красота, — заметил Берсенев. — Кстати, кончил ты свой барельеф?
— Какой?
— Ребенка с козлом.
— К чёрту! к чёрту! к чёрту! — воскликнул нараспев Шубин. — Посмотрел на настоящих, на стариков, на антики, да и разбил свою чепуху. Ты указываешь мне на природу и говоришь: «И тут красота». Конечно, во всем красота, даже и в твоем носе красота, да за всякою красотой не угоняешься. Старики — те за ней и не гонялись; она сама сходила в их создания, откуда — бог весть, с неба, что ли. Им весь мир принадлежал; нам так широко распространяться не приходится: коротки руки. Мы закидываем удочку на одной точечке, да и караулим. Клюнет — браво! а не клюнет...
Шубин высунул язык.
— Постой, постой, — возразил Берсенев. — Это парадокс. Если ты не будешь сочувствовать красоте, любить ее всюду, где бы ты ее ни встретил, так она тебе и в твоем искусстве не дастся. Если прекрасный вид, прекрасная музыка ничего не говорят твоей душе, я хочу сказать, если ты им не сочувствуешь...
— Эх ты, сочувственник! — брякнул Шубин и сам засмеялся новоизобретенному слову, а Берсенев задумался. — Нет, брат, — продолжал Шубин, — ты умница, философ, третий кандидат Московского университета, с тобой спорить страшно, особенно мне, недоучившемуся студенту; но я тебе вот что скажу: кроме своего искусства, я люблю красоту только в женщинах... в девушках, да и то с некоторых пор...
Он перевернулся на спину и заложил руки за голову.
Несколько мгновений прошло в молчании. Тишина полуденного зноя тяготела над сияющей и заснувшей землей.
— Кстати, о женщинах, — заговорил опять Шубин. — Что это никто не возьмет Стахова в руки? Ты видел его в Москве?
— Нет.
— Совсем с ума сошел старец. Сидит по целым дням у своей Августины Христиановны, скучает страшно, а сидит. Глазеют друг на друга, так глупо... Даже противно смотреть. Вот поди ты! Каким семейством бог благословил этого человека: нет, подай ему Августину Христиановну! Я ничего не знаю гнуснее ее утиной физиономии! На днях я вылепил ее карикатуру, в дантановском вкусе. Очень вышло недурно. Я тебе покажу.
— А Елены Николаевны бюст, — спросил Берсенев, — подвигается?
— Нет, брат, не подвигается. От этого лица можно в отчаяние прийти. Посмотришь, линии чистые, строгие, прямые; кажется, нетрудно схватить сходство. Не тут-то было... Не дается, как клад в руки. Заметил ты, как она слушает? Ни одна черта не тронется, только выражение взгляда беспрестанно меняется, а от него меняется вся фигура. Что тут прикажешь делать скульптору, да еще плохому? Удивительное существо... странное существо, — прибавил он после короткого молчания.
— Да; она удивительная девушка, — повторил за ним Берсенев.
— А дочь Николая Артемьевича Стахова! Вот после этого и рассуждай о крови, о породе. И ведь забавно то, что она точно его дочь, похожа на него и на мать похожа, на Анну Васильевну. Я Анну Васильевну уважаю от всего сердца, она же моя благодетельница; но ведь она курица. Откуда же взялась эта душа у Елены? Кто зажег этот огонь? Вот опять тебе задача, философ!"""

doc = nlp(text)

print("=== Токены, Леммы, POS, Синтаксис ===")
for token in doc:
    print(f"{token.text:<15} | {token.lemma_:<20} | {token.pos_:<10} | {token.dep_:<10} | head: {token.head.text}")

print("\n=== Именованные сущности ===")
for ent in doc.ents:
    print(f"{ent.text:<30} | {ent.label_:<10} | {spacy.explain(ent.label_)}")
# Out:
# === Токены, Леммы, POS, Синтаксис ===
#
#                |
#                     | SPACE      | dep        | head: В
# В               | в                    | ADP        | case       | head: тени
# тени            | тень                 | NOUN       | obl        | head: лежали
# высокой         | высокий              | ADJ        | amod       | head: липы
# липы            | липа                 | NOUN       | nmod       | head: тени
# ,               | ,                    | PUNCT      | punct      | head: берегу
# на              | на                   | ADP        | case       | head: берегу
# берегу          | берег                | NOUN       | conj       | head: тени
# Москвы          | москва               | PROPN      | nmod       | head: берегу
# -               | -                    | PROPN      | nmod       | head: берегу
# реки            | река                 | PROPN      | nmod       | head: берегу
# ,               | ,                    | PUNCT      | punct      | head: недалеко
# недалеко        | недалеко             | ADV        | advmod     | head: берегу
# от              | от                   | ADP        | case       | head: Кунцева
# Кунцева         | кунцева              | PROPN      | obl        | head: недалеко
# ,               | ,                    | PUNCT      | punct      | head: один
# в               | в                    | ADP        | case       | head: один
# один            | один                 | NUM        | obl        | head: лежали
# из              | из                   | ADP        | case       | head: дней
# самых           | самых                | ADJ        | amod       | head: жарких
# жарких          | жаркий               | ADJ        | amod       | head: дней
# летних          | летний               | ADJ        | amod       | head: дней
# дней            | день                 | NOUN       | nmod       | head: один
# 1853            | 1853                 | ADJ        | amod       | head: года
# года            | год                  | NOUN       | nmod       | head: дней
# лежали          | лежать               | VERB       | ROOT       | head: лежали
# на              | на                   | ADP        | case       | head: траве
# траве           | трава                | NOUN       | obl        | head: лежали
# два             | два                  | NUM        | nummod:gov | head: человека
# молодых         | молодой              | ADJ        | amod       | head: человека
# человека        | человек              | NOUN       | nsubj      | head: лежали
# .               | .                    | PUNCT      | punct      | head: лежали
# Один            | один                 | NUM        | nsubj      | head: лежал
# ,               | ,                    | PUNCT      | punct      | head: вид
# на              | на                   | ADP        | case       | head: вид
# вид             | вид                  | NOUN       | nmod       | head: Один
# лет             | год                  | NOUN       | nmod       | head: вид
# двадцати        | двадцать             | NUM        | nummod     | head: трех
# трех            | три                  | NUM        | nummod     | head: роста
# ,               | ,                    | PUNCT      | punct      | head: высокого
# высокого        | высокий              | ADJ        | amod       | head: роста
# роста           | рост                 | NOUN       | nmod       | head: лет
# ,               | ,                    | PUNCT      | punct      | head: черномазый
# черномазый      | черномазый           | VERB       | conj       | head: Один
# ,               | ,                    | PUNCT      | punct      | head: носом
# с               | с                    | ADP        | case       | head: носом
# острым          | острый               | ADJ        | amod       | head: носом
# и               | и                    | CCONJ      | cc         | head: немного
# немного         | немного              | ADV        | advmod     | head: кривым
# кривым          | кривой               | ADJ        | amod       | head: носом
# носом           | нос                  | NOUN       | appos      | head: Один
# ,               | ,                    | PUNCT      | punct      | head: лбом
# высоким         | высокий              | ADJ        | amod       | head: лбом
# лбом            | лоб                  | NOUN       | conj       | head: Один
# и               | и                    | CCONJ      | cc         | head: сдержанною
# сдержанною      | сдержанною           | NOUN       | conj       | head: Один
# улыбкой         | улыбка               | NOUN       | nmod       | head: сдержанною
# на              | на                   | ADP        | case       | head: губах
# широких         | широкий              | ADJ        | amod       | head: губах
# губах           | губа                 | NOUN       | nmod       | head: улыбкой
# ,               | ,                    | PUNCT      | punct      | head: Один
# лежал           | лежать               | VERB       | ROOT       | head: лежал
# на              | на                   | ADP        | case       | head: спине
# спине           | спина                | NOUN       | obl        | head: лежал
# и               | и                    | CCONJ      | cc         | head: глядел
# задумчиво       | задумчиво            | ADV        | advmod     | head: глядел
# глядел          | глядеть              | VERB       | conj       | head: лежал
# вдаль           | вдаль                | ADV        | advmod     | head: глядел
# ,               | ,                    | PUNCT      | punct      | head: прищурив
# слегка          | слегка               | ADV        | advmod     | head: прищурив
# прищурив        | прищурить            | VERB       | advcl      | head: глядел
# свои            | свой                 | DET        | det        | head: глазки
# небольшие       | небольшой            | ADJ        | amod       | head: глазки
# серые           | серый                | ADJ        | amod       | head: глазки
# глазки          | глазки               | NOUN       | obj        | head: прищурив
# ;               | ;                    | PUNCT      | punct      | head: лежал
# другой          | другой               | ADJ        | nsubj      | head: лежал
# лежал           | лежать               | VERB       | conj       | head: лежал
# на              | на                   | ADP        | case       | head: груди
# груди           | грудь                | NOUN       | obl        | head: лежал
# ,               | ,                    | PUNCT      | punct      | head: подперев
# подперев        | подпереть            | VERB       | advcl      | head: лежал
# обеими          | оба                  | NUM        | nummod     | head: руками
# руками          | рука                 | NOUN       | obl        | head: подперев
# кудрявую        | кудрявый             | ADJ        | amod       | head: голову
# белокурую       | белокурый            | ADJ        | amod       | head: голову
# голову          | голова               | NOUN       | obj        | head: подперев
# ,               | ,                    | PUNCT      | punct      | head: глядел
# и               | и                    | CCONJ      | cc         | head: глядел
# тоже            | тоже                 | ADV        | advmod     | head: глядел
# глядел          | глядеть              | VERB       | conj       | head: лежал
# куда            | куда                 | ADV        | advmod     | head: вдаль
# -               | -                    | ADV        | advmod     | head: вдаль
# то              | то                   | ADV        | advmod     | head: вдаль
# вдаль           | вдаль                | ADV        | obj        | head: глядел
# .               | .                    | PUNCT      | punct      | head: лежал
# Он              | он                   | PRON       | nsubj      | head: годами
# был             | быть                 | AUX        | cop        | head: годами
# тремя           | три                  | NUM        | nummod     | head: годами
# годами          | год                  | NOUN       | obl        | head: вился
# старше          | старший              | ADJ        | nmod       | head: годами
# своего          | свой                 | DET        | det        | head: товарища
# товарища        | товарищ              | NOUN       | obj        | head: старше
# ,               | ,                    | PUNCT      | punct      | head: казался
# но              | но                   | CCONJ      | cc         | head: казался
# казался         | казаться             | VERB       | conj       | head: годами
# гораздо         | гораздо              | ADV        | advmod     | head: моложе
# моложе          | молодой              | ADJ        | advmod     | head: казался
# ;               | ;                    | PUNCT      | punct      | head: пробились
# усы             | ус                   | NOUN       | nsubj      | head: пробились
# его             | его                  | PRON       | obj        | head: пробились
# едва            | едва                 | PART       | advmod     | head: пробились
# пробились       | пробиться            | VERB       | conj       | head: годами
# и               | и                    | CCONJ      | cc         | head: вился
# на              | на                   | ADP        | case       | head: подбородке
# подбородке      | подбородок           | NOUN       | obl        | head: вился
# вился           | вился                | VERB       | ROOT       | head: вился
# легкий          | лёгкий               | ADJ        | amod       | head: пух
# пух             | пух                  | NOUN       | nsubj      | head: вился
# .               | .                    | PUNCT      | punct      | head: вился
# Было            | Было                 | AUX        | ROOT       | head: Было
# что             | что                  | PRON       | nsubj      | head: Было
# -               | -                    | PRON       | nsubj      | head: Было
# то              | то                   | PRON       | nsubj      | head: Было
# детски          | детски               | ADJ        | nsubj      | head: Было
# -               | -                    | ADJ        | nsubj      | head: Было
# миловидное      | миловидный           | ADJ        | nsubj      | head: Было
# ,               | ,                    | PUNCT      | punct      | head: изящное
# что             | что                  | PRON       | nsubj      | head: изящное
# -               | -                    | PRON       | nsubj      | head: изящное
# то              | то                   | PRON       | nsubj      | head: изящное
# привлекательно  | привлекательно       | ADV        | advmod     | head: изящное
# изящное         | изящное              | VERB       | acl        | head: Было
# в               | в                    | ADP        | case       | head: чертах
# мелких          | мелкий               | ADJ        | amod       | head: чертах
# чертах          | черта                | NOUN       | obl        | head: изящное
# его             | он                   | DET        | det        | head: лица
# свежего         | свежий               | ADJ        | amod       | head: лица
# ,               | ,                    | PUNCT      | punct      | head: круглого
# круглого        | круглый              | ADJ        | conj       | head: свежего
# лица            | лицо                 | NOUN       | nmod       | head: чертах
# ,               | ,                    | PUNCT      | punct      | head: изящное
# в               | в                    | ADP        | case       | head: карих
# его             | он                   | DET        | det        | head: карих
# сладких         | сладкий              | ADJ        | amod       | head: карих
# карих           | карих                | NOUN       | obl        | head: Было
# глазах          | глаз                 | NOUN       | nmod       | head: карих
# ,               | ,                    | PUNCT      | punct      | head: губках
# красивых        | красивый             | ADJ        | amod       | head: губках
# выпуклых        | выпуклый             | ADJ        | amod       | head: губках
# губках          | губках               | NOUN       | conj       | head: глазах
# и               | и                    | CCONJ      | cc         | head: ручках
# белых           | белый                | ADJ        | amod       | head: ручках
# ручках          | ручках               | NOUN       | conj       | head: глазах
# .               | .                    | PUNCT      | punct      | head: Было
# Всё             | всё                  | PROPN      | nsubj      | head: дышало
# в               | в                    | ADP        | case       | head: нем
# нем             | нем                  | PRON       | obl        | head: дышало
# дышало          | дышать               | VERB       | ROOT       | head: дышало
# счастливою      | счастливою           | VERB       | obj        | head: дышало
# веселостью      | весёлость            | NOUN       | obl        | head: дышало
# здоровья        | здоровье             | NOUN       | nmod       | head: веселостью
# ,               | ,                    | PUNCT      | punct      | head: дышало
# дышало          | дышать               | VERB       | conj       | head: дышало
# молодостью      | молодость            | NOUN       | obj        | head: дышало
# —               | —                    | PUNCT      | punct      | head: беспечностью
# беспечностью    | беспечность          | NOUN       | parataxis  | head: молодостью
# ,               | ,                    | PUNCT      | punct      | head: самонадеянностью
# самонадеянностью | самонадеянность      | NOUN       | conj       | head: беспечностью
# ,               | ,                    | PUNCT      | punct      | head: избалованностью
# избалованностью | избалованность       | NOUN       | conj       | head: беспечностью
# ,               | ,                    | PUNCT      | punct      | head: прелестью
# прелестью       | прелесть             | NOUN       | conj       | head: беспечностью
# молодости       | молодость            | NOUN       | nmod       | head: прелестью
# .               | .                    | PUNCT      | punct      | head: дышало
# Он              | он                   | PRON       | nsubj      | head: поводил
# и               | и                    | CCONJ      | advmod     | head: поводил
# поводил         | поводить             | VERB       | ROOT       | head: поводил
# глазами         | глаз                 | NOUN       | iobj       | head: поводил
# ,               | ,                    | PUNCT      | punct      | head: улыбался
# и               | и                    | CCONJ      | cc         | head: улыбался
# улыбался        | улыбаться            | VERB       | conj       | head: поводил
# ,               | ,                    | PUNCT      | punct      | head: подпирал
# и               | и                    | CCONJ      | cc         | head: подпирал
# подпирал        | подпирал             | VERB       | conj       | head: поводил
# голову          | голова               | NOUN       | obj        | head: подпирал
# ,               | ,                    | PUNCT      | punct      | head: делают
# как             | как                  | SCONJ      | mark       | head: делают
# это             | это                  | PRON       | obj        | head: делают
# делают          | делать               | VERB       | advcl      | head: подпирал
# мальчики        | мальчик              | NOUN       | nsubj      | head: делают
# ,               | ,                    | PUNCT      | punct      | head: знают
# которые         | которые              | PRON       | nsubj      | head: знают
# знают           | знать                | VERB       | acl:relcl  | head: мальчики
# ,               | ,                    | PUNCT      | punct      | head: заглядываются
# что             | что                  | SCONJ      | mark       | head: заглядываются
# на              | на                   | ADP        | case       | head: них
# них             | них                  | PRON       | obl        | head: заглядываются
# охотно          | охотно               | ADV        | advmod     | head: заглядываются
# заглядываются   | заглядываются        | VERB       | ccomp      | head: знают
# .               | .                    | PUNCT      | punct      | head: поводил
# На              | на                   | ADP        | case       | head: нем
# нем             | нем                  | PRON       | obl        | head: было
# было            | было                 | AUX        | ROOT       | head: было
# просторное      | просторный           | ADJ        | amod       | head: пальто
# белое           | белый                | ADJ        | amod       | head: пальто
# пальто          | пальто               | NOUN       | nsubj      | head: было
# вроде           | вроде                | ADP        | case       | head: блузы
# блузы           | блуза                | NOUN       | nmod       | head: пальто
# ;               | ;                    | PUNCT      | punct      | head: охватывал
# голубой         | голубой              | ADJ        | amod       | head: платок
# платок          | платок               | NOUN       | nsubj      | head: охватывал
# охватывал       | охватывал            | VERB       | conj       | head: было
# его             | он                   | DET        | det        | head: шею
# тонкую          | тонкий               | ADJ        | amod       | head: шею
# шею             | шея                  | NOUN       | obj        | head: охватывал
# ,               | ,                    | PUNCT      | punct      | head: валялась
# измятая         | измятый              | ADJ        | amod       | head: шляпа
# соломенная      | соломенный           | ADJ        | amod       | head: шляпа
# шляпа           | шляпа                | NOUN       | nsubj      | head: валялась
# валялась        | валяться             | VERB       | acl:relcl  | head: шею
# в               | в                    | ADP        | case       | head: траве
# траве           | трава                | NOUN       | obl        | head: валялась
# возле           | возле                | ADP        | case       | head: него
# него            | него                 | PRON       | nmod       | head: траве
# .               | .                    | PUNCT      | punct      | head: было
#
#                |
#                     | SPACE      | dep        | head: .
# В               | в                    | ADP        | case       | head: сравнении
# сравнении       | сравнение            | NOUN       | obl        | head: казался
# с               | с                    | ADP        | case       | head: ним
# ним             | ним                  | PRON       | nmod       | head: сравнении
# его             | его                  | PRON       | nmod       | head: товарищ
# товарищ         | товарищ              | NOUN       | nsubj      | head: казался
# казался         | казаться             | VERB       | ROOT       | head: казался
# стариком        | старик               | NOUN       | obl        | head: казался
# ,               | ,                    | PUNCT      | punct      | head: подумал
# и               | и                    | CCONJ      | cc         | head: подумал
# никто           | никто                | PRON       | nsubj      | head: подумал
# бы              | бы                   | AUX        | aux        | head: подумал
# не              | не                   | PART       | advmod     | head: подумал
# подумал         | подумать             | VERB       | conj       | head: казался
# ,               | ,                    | PUNCT      | punct      | head: глядя
# глядя           | глядеть              | VERB       | advcl      | head: подумал
# на              | на                   | ADP        | case       | head: фигуру
# его             | он                   | DET        | det        | head: фигуру
# угловатую       | угловатый            | ADJ        | amod       | head: фигуру
# фигуру          | фигура               | NOUN       | obl        | head: глядя
# ,               | ,                    | PUNCT      | punct      | head: наслаждается
# что             | что                  | PRON       | mark       | head: наслаждается
# и               | и                    | CCONJ      | advmod     | head: он
# он              | он                   | PRON       | nsubj      | head: наслаждается
# наслаждается    | наслаждаться         | VERB       | ccomp      | head: глядя
# ,               | ,                    | PUNCT      | punct      | head: хорошо
# что             | что                  | SCONJ      | mark       | head: хорошо
# и               | и                    | CCONJ      | advmod     | head: ему
# ему             | ему                  | PRON       | iobj       | head: хорошо
# хорошо          | хороший              | ADJ        | ccomp      | head: наслаждается
# .               | .                    | PUNCT      | punct      | head: казался
# Он              | он                   | PRON       | nsubj      | head: лежал
# лежал           | лежать               | VERB       | ROOT       | head: лежал
# неловко         | неловко              | ADV        | advmod     | head: лежал
# ;               | ;                    | PUNCT      | punct      | head: сидела
# его             | он                   | DET        | det        | head: сидела
# большая         | больший              | ADJ        | amod       | head: его
# ,               | ,                    | PUNCT      | punct      | head: кверху
# кверху          | кверху               | NOUN       | conj       | head: его
# широкая         | широкий              | ADJ        | amod       | head: кверху
# ,               | ,                    | PUNCT      | punct      | head: сидела
# книзу           | книзу                | ADV        | advmod     | head: заостренная
# заостренная     | заостренная          | ADJ        | amod       | head: голова
# голова          | голова               | NOUN       | nsubj      | head: сидела
# неловко         | неловко              | ADV        | advmod     | head: сидела
# сидела          | сидеть               | VERB       | conj       | head: лежал
# на              | на                   | ADP        | case       | head: шее
# длинной         | длинный              | ADJ        | amod       | head: шее
# шее             | шея                  | NOUN       | obl        | head: сидела
# ;               | ;                    | PUNCT      | punct      | head: сказывалась
# неловкость      | неловкость           | NOUN       | nsubj      | head: сказывалась
# сказывалась     | сказывалась          | VERB       | conj       | head: лежал
# в               | в                    | ADP        | case       | head: положении
# самом           | самом                | ADJ        | amod       | head: положении
# положении       | положение            | NOUN       | obl        | head: сказывалась
# его             | он                   | DET        | det        | head: рук
# рук             | рука                 | NOUN       | nmod       | head: положении
# ,               | ,                    | PUNCT      | punct      | head: туловища
# его             | он                   | DET        | det        | head: туловища
# туловища        | туловище             | NOUN       | conj       | head: рук
# ,               | ,                    | PUNCT      | punct      | head: охваченного
# плотно          | плотно               | ADV        | advmod     | head: охваченного
# охваченного     | охватить             | VERB       | acl        | head: туловища
# коротким        | короткий             | ADJ        | amod       | head: сюртучком
# черным          | чёрный               | ADJ        | amod       | head: сюртучком
# сюртучком       | сюртучок             | NOUN       | obl:agent  | head: охваченного
# ,               | ,                    | PUNCT      | punct      | head: ног
# его             | он                   | DET        | det        | head: ног
# длинных         | длинный              | ADJ        | amod       | head: ног
# ног             | нога                 | NOUN       | conj       | head: рук
# с               | с                    | ADP        | case       | head: коленями
# поднятыми       | поднять              | VERB       | amod       | head: коленями
# коленями        | колено               | NOUN       | nmod       | head: ног
# ,               | ,                    | PUNCT      | punct      | head: подобных
# подобных        | подобный             | ADJ        | acl        | head: коленями
# задним          | задний               | ADJ        | amod       | head: ножкам
# ножкам          | ножкам               | NOUN       | iobj       | head: подобных
# стрекозы        | стрекоза             | NOUN       | nmod       | head: ножкам
# .               | .                    | PUNCT      | punct      | head: лежал
# Со              | Со                   | ADP        | case       | head: тем
# всем            | весь                 | DET        | det        | head: тем
# тем             | тем                  | PRON       | obl        | head: нельзя
# нельзя          | нельзя               | ADV        | ROOT       | head: нельзя
# было            | было                 | AUX        | cop        | head: нельзя
# не              | не                   | PART       | advmod     | head: признать
# признать        | признать             | VERB       | csubj      | head: нельзя
# в               | в                    | ADP        | case       | head: нем
# нем             | нем                  | PRON       | obl        | head: признать
# хорошо          | хорошо               | ADV        | advmod     | head: воспитанного
# воспитанного    | воспитанный          | ADJ        | acl        | head: человека
# человека        | человек              | NOUN       | obj        | head: признать
# ;               | ;                    | PUNCT      | punct      | head: нельзя
# отпечаток       | отпечаток            | NOUN       | nsubj      | head: замечался
# «               | "                    | PUNCT      | punct      | head: порядочности
# порядочности    | порядочность         | NOUN       | nmod       | head: отпечаток
# »               | "                    | PUNCT      | punct      | head: порядочности
# замечался       | замечался            | VERB       | conj       | head: нельзя
# во              | в                    | ADP        | case       | head: существе
# всем            | всем                 | PRON       | det        | head: существе
# его             | он                   | DET        | det        | head: существе
# неуклюжем       | неуклюжий            | ADJ        | amod       | head: существе
# существе        | существо             | NOUN       | obl        | head: замечался
# ,               | ,                    | PUNCT      | punct      | head: смешное
# и               | и                    | CCONJ      | cc         | head: смешное
# лицо            | лицо                 | NOUN       | nsubj      | head: смешное
# его             | его                  | PRON       | det        | head: лицо
# ,               | ,                    | PUNCT      | punct      | head: некрасивое
# некрасивое      | некрасивый           | ADJ        | amod       | head: его
# и               | и                    | CCONJ      | cc         | head: несколько
# даже            | даже                 | PART       | advmod     | head: несколько
# несколько       | несколько            | NUM        | nummod:gov | head: смешное
# смешное         | смешной              | ADJ        | conj       | head: замечался
# ,               | ,                    | PUNCT      | punct      | head: выражало
# выражало        | выражало             | VERB       | conj       | head: замечался
# привычку        | привычка             | NOUN       | obj        | head: выражало
# мыслить         | мыслить              | VERB       | nmod       | head: привычку
# и               | и                    | PART       | advmod     | head: доброту
# доброту         | доброта              | NOUN       | obj        | head: мыслить
# .               | .                    | PUNCT      | punct      | head: нельзя
# Звали           | звать                | VERB       | ROOT       | head: Звали
# его             | его                  | PRON       | obj        | head: Звали
# Андреем         | андрей               | PROPN      | xcomp      | head: Звали
# Петровичем      | петрович             | PROPN      | flat:name  | head: Андреем
# Берсеневым      | берсенев             | PROPN      | flat:name  | head: Андреем
# ;               | ;                    | PUNCT      | punct      | head: прозывался
# его             | его                  | PRON       | nmod       | head: товарищ
# товарищ         | товарищ              | NOUN       | nsubj      | head: прозывался
# ,               | ,                    | PUNCT      | punct      | head: человек
# белокурый       | белокурый            | ADJ        | amod       | head: человек
# молодой         | молодой              | ADJ        | amod       | head: человек
# человек         | человек              | NOUN       | appos      | head: товарищ
# ,               | ,                    | PUNCT      | punct      | head: прозывался
# прозывался      | прозывался           | VERB       | conj       | head: Звали
# Шубиным         | шубиным              | ADJ        | iobj       | head: прозывался
# ,               | ,                    | PUNCT      | punct      | head: Павлом
# Павлом          | павел                | PROPN      | conj       | head: Шубиным
# Яковлевичем     | яковлевич            | PROPN      | flat:name  | head: Павлом
# .               | .                    | PUNCT      | punct      | head: лежишь
#
#                |
#                     | SPACE      | dep        | head: .
# —               | —                    | PUNCT      | punct      | head: лежишь
# Отчего          | Отчего               | ADV        | advmod     | head: лежишь
# ты              | ты                   | PRON       | nsubj      | head: лежишь
# не              | не                   | PART       | advmod     | head: лежишь
# лежишь          | лежать               | VERB       | conj       | head: Звали
# ,               | ,                    | PUNCT      | punct      | head: груди
# как             | как                  | SCONJ      | case       | head: груди
# я               | я                    | PRON       | nsubj      | head: груди
# ,               | ,                    | PUNCT      | punct      | head: груди
# на              | на                   | ADP        | case       | head: груди
# груди           | грудь                | NOUN       | obl        | head: лежишь
# ?               | ?                    | PUNCT      | punct      | head: Звали
# —               | —                    | PUNCT      | punct      | head: начал
# начал           | начать               | VERB       | parataxis  | head: Звали
# Шубин           | шубин                | PROPN      | nsubj      | head: начал
# .               | .                    | PUNCT      | punct      | head: Звали
# —               | —                    | PUNCT      | punct      | head: лучше
# Так             | так                  | ADV        | advmod     | head: лучше
# гораздо         | гораздо              | ADV        | advmod     | head: лучше
# лучше           | хороший              | ADJ        | ROOT       | head: лучше
# .               | .                    | PUNCT      | punct      | head: лучше
# Особенно        | Особенно             | ADV        | advmod     | head: поднимешь
# когда           | когда                | SCONJ      | mark       | head: поднимешь
# поднимешь       | поднимешь            | VERB       | csubj      | head: так
# ноги            | нога                 | NOUN       | obj        | head: поднимешь
# и               | и                    | CCONJ      | cc         | head: стучишь
# стучишь         | стучать              | VERB       | conj       | head: поднимешь
# каблуками       | каблук               | NOUN       | obl        | head: стучишь
# дружку          | дружку               | NOUN       | obj        | head: стучишь
# о               | о                    | ADP        | case       | head: дружку
# дружку          | дружку               | NOUN       | nmod       | head: дружку
# —               | —                    | PUNCT      | punct      | head: так
# вот             | вот                  | PART       | advmod     | head: так
# так             | так                  | ADV        | ROOT       | head: так
# .               | .                    | PUNCT      | punct      | head: так
# Трава           | трава                | NOUN       | ROOT       | head: Трава
# под             | под                  | ADP        | case       | head: носом
# носом           | нос                  | NOUN       | nmod       | head: Трава
# :               | :                    | PUNCT      | punct      | head: надоест
# надоест         | надоест              | VERB       | parataxis  | head: Трава
# глазеть         | глазеть              | VERB       | xcomp      | head: надоест
# на              | на                   | ADP        | case       | head: пейзаж
# пейзаж          | пейзаж               | NOUN       | obl        | head: глазеть
# —               | —                    | PUNCT      | punct      | head: смотри
# смотри          | смотреть             | VERB       | parataxis  | head: надоест
# на              | на                   | ADP        | case       | head: козявку
# какую           | какой                | DET        | det        | head: козявку
# -               | -                    | DET        | det        | head: козявку
# нибудь          | нибудь               | DET        | det        | head: козявку
# пузатую         | пузатый              | ADJ        | amod       | head: козявку
# козявку         | козявка              | NOUN       | obl        | head: смотри
# ,               | ,                    | PUNCT      | punct      | head: ползет
# как             | как                  | SCONJ      | mark       | head: ползет
# она             | она                  | PRON       | nsubj      | head: ползет
# ползет          | ползти               | VERB       | advcl      | head: смотри
# по              | по                   | ADP        | case       | head: былинке
# былинке         | былинка              | NOUN       | obl        | head: ползет
# ,               | ,                    | PUNCT      | punct      | head: муравья
# или             | или                  | CCONJ      | cc         | head: муравья
# на              | на                   | ADP        | case       | head: муравья
# муравья         | муравья              | NOUN       | conj       | head: былинке
# ,               | ,                    | PUNCT      | punct      | head: суетится
# как             | как                  | SCONJ      | mark       | head: суетится
# он              | он                   | PRON       | nsubj      | head: суетится
# суетится        | суетится             | VERB       | advcl      | head: ползет
# .               | .                    | PUNCT      | punct      | head: Трава
# Право           | право                | NOUN       | nsubj      | head: лучше
# ,               | ,                    | PUNCT      | punct      | head: Право
# так             | так                  | ADV        | advmod     | head: лучше
# лучше           | хороший              | ADJ        | ROOT       | head: лучше
# .               | .                    | PUNCT      | punct      | head: лучше
# А               | а                    | CCONJ      | cc         | head: принял
# то              | то                   | PRON       | mark       | head: принял
# ты              | ты                   | PRON       | nsubj      | head: принял
# принял          | принять              | VERB       | ROOT       | head: принял
# теперь          | теперь               | ADV        | advmod     | head: принял
# какую           | какой                | DET        | det        | head: позу
# -               | -                    | DET        | det        | head: позу
# то              | то                   | DET        | det        | head: позу
# псевдоклассическую | псевдоклассический   | ADJ        | amod       | head: позу
# позу            | поза                 | NOUN       | obj        | head: принял
# ,               | ,                    | PUNCT      | punct      | head: дать
# ни              | ни                   | CCONJ      | cc         | head: дать
# дать            | дать                 | VERB       | conj       | head: принял
# ни              | ни                   | CCONJ      | cc         | head: взять
# взять           | взять                | VERB       | xcomp      | head: дать
# танцовщица      | танцовщица           | NOUN       | obj        | head: дать
# в               | в                    | ADP        | case       | head: балете
# балете          | балет                | NOUN       | obl        | head: дать
# ,               | ,                    | PUNCT      | punct      | head: облокачивается
# когда           | когда                | SCONJ      | mark       | head: облокачивается
# она             | она                  | PRON       | nsubj      | head: облокачивается
# облокачивается  | облокачиваться       | VERB       | advcl      | head: дать
# на              | на                   | ADP        | case       | head: утес
# картонный       | картонный            | ADJ        | amod       | head: утес
# утес            | утёс                 | NOUN       | obl        | head: облокачивается
# .               | .                    | PUNCT      | punct      | head: принял
# Ты              | ты                   | PRON       | nsubj      | head: вспомни
# вспомни         | вспомни              | VERB       | ROOT       | head: вспомни
# ,               | ,                    | PUNCT      | punct      | head: имеешь
# что             | что                  | SCONJ      | mark       | head: имеешь
# ты              | ты                   | PRON       | nsubj      | head: имеешь
# теперь          | теперь               | ADV        | advmod     | head: имеешь
# имеешь          | иметь                | VERB       | ccomp      | head: вспомни
# полное          | полный               | ADJ        | amod       | head: право
# право           | право                | NOUN       | obj        | head: имеешь
# отдыхать        | отдыхать             | VERB       | nmod       | head: право
# .               | .                    | PUNCT      | punct      | head: вспомни
# Шутка           | шутка                | NOUN       | obj        | head: сказать
# сказать         | сказать              | VERB       | ROOT       | head: сказать
# :               | :                    | PUNCT      | punct      | head: вышел
# вышел           | выйти                | VERB       | parataxis  | head: сказать
# третьим         | третий               | ADJ        | amod       | head: кандидатом
# кандидатом      | кандидат             | NOUN       | obl        | head: вышел
# !               | !                    | PUNCT      | punct      | head: сказать
# Отдохните       | отдохнуть            | VERB       | ROOT       | head: Отдохните
# ,               | ,                    | PUNCT      | punct      | head: сэр
# сэр             | сэр                  | NOUN       | parataxis  | head: Отдохните
# ;               | ;                    | PUNCT      | punct      | head: перестаньте
# перестаньте     | перестать            | VERB       | conj       | head: Отдохните
# напрягаться     | напрягаться          | VERB       | xcomp      | head: перестаньте
# ,               | ,                    | PUNCT      | punct      | head: раскиньте
# раскиньте       | раскинуть            | VERB       | conj       | head: перестаньте
# свои            | свой                 | DET        | det        | head: члены
# члены           | член                 | NOUN       | obj        | head: раскиньте
# !               | !                    | PUNCT      | punct      | head: Отдохните
#
#                |
#                     | SPACE      | dep        | head: !
# Шубин           | шубин                | PROPN      | nsubj      | head: произнес
# произнес        | произнести           | VERB       | ROOT       | head: произнес
# всю             | весь                 | DET        | det        | head: речь
# эту             | этот                 | DET        | det        | head: речь
# речь            | речь                 | NOUN       | obj        | head: произнес
# в               | в                    | ADP        | case       | head: нос
# нос             | нос                  | NOUN       | obl        | head: произнес
# ,               | ,                    | PUNCT      | punct      | head: полулениво
# полулениво      | полулениво           | ADV        | advmod     | head: произнес
# ,               | ,                    | PUNCT      | punct      | head: полушутливо
# полушутливо     | полушутливо          | ADV        | conj       | head: произнес
# (               | (                    | PUNCT      | punct      | head: говорят
# балованные      | балованный           | ADJ        | amod       | head: дети
# дети            | ребёнок              | NOUN       | nsubj      | head: говорят
# говорят         | говорить             | VERB       | parataxis  | head: полушутливо
# так             | так                  | ADV        | advmod     | head: говорят
# с               | с                    | ADP        | case       | head: друзьями
# друзьями        | друг                 | NOUN       | obl        | head: так
# дома            | дом                  | NOUN       | nmod       | head: друзьями
# ,               | ,                    | PUNCT      | punct      | head: привозят
# которые         | которые              | PRON       | nsubj      | head: привозят
# привозят        | привозить            | VERB       | acl:relcl  | head: дома
# им              | им                   | PRON       | iobj       | head: привозят
# конфекты        | конфекты             | NOUN       | obj        | head: привозят
# )               | )                    | PUNCT      | punct      | head: говорят
# ,               | ,                    | PUNCT      | punct      | head: продолжал
# и               | и                    | CCONJ      | cc         | head: продолжал
# ,               | ,                    | PUNCT      | punct      | head: дождавшись
# не              | не                   | PART       | advmod     | head: дождавшись
# дождавшись      | дождаться            | VERB       | advcl      | head: продолжал
# ответа          | ответ                | NOUN       | obj        | head: дождавшись
# ,               | ,                    | PUNCT      | punct      | head: дождавшись
# продолжал       | продолжать           | VERB       | conj       | head: произнес
# :               | :                    | PUNCT      | punct      | head: поражает
#
#                |
#                     | SPACE      | dep        | head: :
# —               | —                    | PUNCT      | punct      | head: поражает
# Меня            | меня                 | PRON       | obj        | head: поражает
# больше          | больше               | NUM        | nummod:gov | head: всего
# всего           | всего                | PRON       | obj        | head: поражает
# поражает        | поражать             | VERB       | parataxis  | head: продолжал
# в               | в                    | ADP        | case       | head: муравьях
# муравьях        | муравьях             | NOUN       | obl        | head: поражает
# ,               | ,                    | PUNCT      | punct      | head: жуках
# жуках           | жуках                | NOUN       | conj       | head: муравьях
# и               | и                    | CCONJ      | cc         | head: господах
# других          | других               | ADJ        | amod       | head: господах
# господах        | господин             | NOUN       | conj       | head: муравьях
# насекомых       | насекомое            | NOUN       | nmod       | head: господах
# их              | они                  | DET        | det        | head: серьезность
# удивительная    | удивительный         | ADJ        | amod       | head: серьезность
# серьезность     | серьёзность          | NOUN       | nsubj      | head: поражает
# ;               | ;                    | PUNCT      | punct      | head: бегают
# бегают          | бегать               | VERB       | conj       | head: поражает
# взад            | взад                 | ADV        | advmod     | head: бегают
# и               | и                    | CCONJ      | cc         | head: вперед
# вперед          | вперёд               | ADV        | conj       | head: взад
# с               | с                    | ADP        | case       | head: физиономиями
# такими          | такой                | DET        | det        | head: физиономиями
# важными         | важный               | ADJ        | amod       | head: физиономиями
# физиономиями    | физиономия           | NOUN       | obl        | head: бегают
# ,               | ,                    | PUNCT      | punct      | head: значит
# точно           | точно                | ADV        | advmod     | head: жизнь
# и               | и                    | PART       | fixed      | head: точно
# их              | они                  | DET        | det        | head: жизнь
# жизнь           | жизнь                | NOUN       | obj        | head: значит
# что             | что                  | PRON       | obj        | head: значит
# -               | -                    | PRON       | obj        | head: значит
# то              | то                   | PRON       | obj        | head: значит
# значит          | значить              | VERB       | conj       | head: поражает
# !               | !                    | PUNCT      | punct      | head: произнес
# Помилуйте       | помилуйте            | VERB       | ROOT       | head: Помилуйте
# ,               | ,                    | PUNCT      | punct      | head: человек
# человек         | человек              | NOUN       | conj       | head: Помилуйте
# ,               | ,                    | PUNCT      | punct      | head: царь
# царь            | царь                 | NOUN       | conj       | head: Помилуйте
# созданья        | созданья             | PROPN      | nmod       | head: царь
# ,               | ,                    | PUNCT      | punct      | head: существо
# существо        | существо             | NOUN       | nsubj      | head: высшее
# высшее          | высокий              | ADJ        | conj       | head: Помилуйте
# ,               | ,                    | PUNCT      | punct      | head: взирает
# на              | на                   | ADP        | case       | head: них
# них             | них                  | PRON       | obl        | head: взирает
# взирает         | взирать              | VERB       | conj       | head: Помилуйте
# ,               | ,                    | PUNCT      | punct      | head: нет
# а               | а                    | CCONJ      | cc         | head: нет
# им              | им                   | PRON       | iobj       | head: нет
# и               | и                    | CCONJ      | cc         | head: дела
# дела            | дело                 | NOUN       | conj       | head: им
# до              | до                   | ADP        | case       | head: него
# него            | него                 | PRON       | obl        | head: нет
# нет             | нет                  | VERB       | conj       | head: Помилуйте
# ;               | ;                    | PUNCT      | punct      | head: сядет
# еще             | ещё                  | ADV        | advmod     | head: сядет
# ,               | ,                    | PUNCT      | punct      | head: пожалуй
# пожалуй         | пожалуй              | ADV        | parataxis  | head: сядет
# ,               | ,                    | PUNCT      | punct      | head: пожалуй
# иной            | иной                 | ADJ        | amod       | head: комар
# комар           | комар                | NOUN       | nsubj      | head: сядет
# сядет           | сесть                | VERB       | conj       | head: Помилуйте
# на              | на                   | ADP        | case       | head: нос
# нос             | нос                  | NOUN       | obl        | head: сядет
# царю            | царь                 | NOUN       | iobj       | head: сядет
# ...
# строгие         | строгий              | ADJ        | conj       | head: чистые
# ,               | ,                    | PUNCT      | punct      | head: прямые
# прямые          | прямой               | ADJ        | conj       | head: Посмотришь
# ;               | ;                    | PUNCT      | punct      | head: кажется
# кажется         | казаться             | VERB       | parataxis  | head: нетрудно
# ,               | ,                    | PUNCT      | punct      | head: кажется
# нетрудно        | нетрудный            | ADJ        | conj       | head: Посмотришь
# схватить        | схватить             | VERB       | csubj      | head: нетрудно
# сходство        | сходство             | NOUN       | obj        | head: схватить
# .               | .                    | PUNCT      | punct      | head: Посмотришь
# Не              | не                   | PART       | advmod     | head: тут
# тут             | тут                  | ADV        | nsubj      | head: было
# -               | -                    | ADV        | nsubj      | head: было
# то              | то                   | ADV        | advmod     | head: было
# было            | быть                 | VERB       | ROOT       | head: было
# ...             | ...                  | PUNCT      | punct      | head: было
# Не              | не                   | PART       | advmod     | head: дается
# дается          | даваться             | VERB       | ROOT       | head: дается
# ,               | ,                    | PUNCT      | punct      | head: клад
# как             | как                  | SCONJ      | case       | head: клад
# клад            | клад                 | NOUN       | obl        | head: дается
# в               | в                    | ADP        | case       | head: руки
# руки            | рука                 | NOUN       | nmod       | head: клад
# .               | .                    | PUNCT      | punct      | head: дается
# Заметил         | заметить             | VERB       | ROOT       | head: Заметил
# ты              | ты                   | PRON       | nsubj      | head: Заметил
# ,               | ,                    | PUNCT      | punct      | head: слушает
# как             | как                  | SCONJ      | mark       | head: слушает
# она             | она                  | PRON       | nsubj      | head: слушает
# слушает         | слушать              | VERB       | ccomp      | head: Заметил
# ?               | ?                    | PUNCT      | punct      | head: Заметил
# Ни              | ни                   | PART       | advmod     | head: одна
# одна            | одна                 | NUM        | nummod     | head: черта
# черта           | черта                | NOUN       | nsubj      | head: тронется
# не              | не                   | PART       | advmod     | head: тронется
# тронется        | тронуться            | VERB       | ROOT       | head: тронется
# ,               | ,                    | PUNCT      | punct      | head: меняется
# только          | только               | PART       | advmod     | head: выражение
# выражение       | выражение            | NOUN       | nsubj      | head: меняется
# взгляда         | взгляд               | NOUN       | nmod       | head: выражение
# беспрестанно    | беспрестанно         | ADV        | advmod     | head: меняется
# меняется        | меняться             | VERB       | conj       | head: тронется
# ,               | ,                    | PUNCT      | punct      | head: меняется
# а               | а                    | CCONJ      | cc         | head: меняется
# от              | от                   | ADP        | case       | head: него
# него            | него                 | PRON       | obl        | head: меняется
# меняется        | меняться             | VERB       | conj       | head: тронется
# вся             | весь                 | DET        | det        | head: фигура
# фигура          | фигура               | NOUN       | nsubj      | head: меняется
# .               | .                    | PUNCT      | punct      | head: тронется
# Что             | что                  | PRON       | obj        | head: прикажешь
# тут             | тут                  | ADV        | advmod     | head: прикажешь
# прикажешь       | прикажешь            | VERB       | ROOT       | head: прикажешь
# делать          | делать               | VERB       | xcomp      | head: прикажешь
# скульптору      | скульптор            | NOUN       | obj        | head: делать
# ,               | ,                    | PUNCT      | punct      | head: плохому
# да              | да                   | CCONJ      | cc         | head: плохому
# еще             | ещё                  | ADV        | advmod     | head: плохому
# плохому         | плохой               | ADJ        | conj       | head: делать
# ?               | ?                    | PUNCT      | punct      | head: прикажешь
# Удивительное    | удивительный         | ADJ        | amod       | head: существо
# существо        | существо             | NOUN       | ROOT       | head: существо
# ...             | ...                  | PUNCT      | punct      | head: существо
# странное        | странный             | ADJ        | amod       | head: существо
# существо        | существо             | NOUN       | nsubj      | head: девушка
# ,               | ,                    | PUNCT      | punct      | head: прибавил
# —               | —                    | PUNCT      | punct      | head: прибавил
# прибавил        | прибавить            | VERB       | parataxis  | head: существо
# он              | он                   | PRON       | nsubj      | head: прибавил
# после           | после                | ADP        | case       | head: молчания
# короткого       | короткий             | ADJ        | amod       | head: молчания
# молчания        | молчание             | NOUN       | obl        | head: прибавил
# .               | .                    | PUNCT      | punct      | head: существо
#
#                |
#                     | SPACE      | dep        | head: .
# —               | —                    | PUNCT      | punct      | head: Да
# Да              | да                   | PART       | parataxis  | head: девушка
# ;               | ;                    | PUNCT      | punct      | head: Да
# она             | она                  | PRON       | nsubj      | head: девушка
# удивительная    | удивительный         | ADJ        | amod       | head: девушка
# девушка         | девушка              | NOUN       | ROOT       | head: девушка
# ,               | ,                    | PUNCT      | punct      | head: повторил
# —               | —                    | PUNCT      | punct      | head: повторил
# повторил        | повторить            | VERB       | parataxis  | head: девушка
# за              | за                   | ADP        | case       | head: ним
# ним             | ним                  | PRON       | obl        | head: повторил
# Берсенев        | берсенев             | PROPN      | nsubj      | head: повторил
# .               | .                    | PUNCT      | punct      | head: дочь
#
#                |
#                     | SPACE      | dep        | head: .
# —               | —                    | PUNCT      | punct      | head: дочь
# А               | а                    | CCONJ      | cc         | head: дочь
# дочь            | дочь                 | NOUN       | conj       | head: девушка
# Николая         | николай              | PROPN      | nmod       | head: дочь
# Артемьевича     | артемиевич           | PROPN      | flat:name  | head: Николая
# Стахова         | стахова              | PROPN      | flat:name  | head: Николая
# !               | !                    | PUNCT      | punct      | head: девушка
# Вот             | вот                  | PART       | advmod     | head: этого
# после           | после                | ADP        | case       | head: этого
# этого           | это                  | PRON       | ROOT       | head: этого
# и               | и                    | CCONJ      | cc         | head: рассуждай
# рассуждай       | рассуждать           | VERB       | conj       | head: этого
# о               | о                    | ADP        | case       | head: крови
# крови           | кровь                | NOUN       | obl        | head: рассуждай
# ,               | ,                    | PUNCT      | punct      | head: породе
# о               | о                    | ADP        | case       | head: породе
# породе          | породе               | NOUN       | conj       | head: крови
# .               | .                    | PUNCT      | punct      | head: этого
# И               | и                    | CCONJ      | cc         | head: забавно
# ведь            | ведь                 | PART       | advmod     | head: забавно
# забавно         | забавный             | ADJ        | ROOT       | head: забавно
# то              | то                   | PRON       | nsubj      | head: похожа
# ,               | ,                    | PUNCT      | punct      | head: дочь
# что             | что                  | SCONJ      | mark       | head: дочь
# она             | она                  | PRON       | nsubj      | head: дочь
# точно           | точно                | ADV        | advmod     | head: дочь
# его             | его                  | PRON       | nmod       | head: дочь
# дочь            | дочь                 | NOUN       | acl        | head: то
# ,               | ,                    | PUNCT      | punct      | head: похожа
# похожа          | похожий              | ADJ        | parataxis  | head: забавно
# на              | на                   | ADP        | case       | head: него
# него            | него                 | PRON       | obl        | head: похожа
# и               | и                    | CCONJ      | cc         | head: похожа
# на              | на                   | ADP        | case       | head: мать
# мать            | мать                 | NOUN       | obl        | head: похожа
# похожа          | похожий              | ADJ        | conj       | head: похожа
# ,               | ,                    | PUNCT      | punct      | head: Анну
# на              | на                   | ADP        | case       | head: Анну
# Анну            | анна                 | PROPN      | obl        | head: похожа
# Васильевну      | василиевич           | PROPN      | flat:name  | head: Анну
# .               | .                    | PUNCT      | punct      | head: забавно
# Я               | я                    | PRON       | nsubj      | head: уважаю
# Анну            | анна                 | PROPN      | appos      | head: Я
# Васильевну      | васильевну           | PROPN      | flat:name  | head: Анну
# уважаю          | уважать              | VERB       | ROOT       | head: уважаю
# от              | от                   | ADP        | case       | head: сердца
# всего           | весь                 | DET        | det        | head: сердца
# сердца          | сердце               | NOUN       | obl        | head: уважаю
# ,               | ,                    | PUNCT      | punct      | head: благодетельница
# она             | она                  | PRON       | nsubj      | head: благодетельница
# же              | же                   | PART       | advmod     | head: она
# моя             | мой                  | DET        | det        | head: благодетельница
# благодетельница | благодетельница      | NOUN       | conj       | head: уважаю
# ;               | ;                    | PUNCT      | punct      | head: курица
# но              | но                   | CCONJ      | cc         | head: курица
# ведь            | ведь                 | PART       | advmod     | head: курица
# она             | она                  | PRON       | nsubj      | head: курица
# курица          | курица               | NOUN       | conj       | head: уважаю
# .               | .                    | PUNCT      | punct      | head: уважаю
# Откуда          | откуда               | ADV        | advmod     | head: взялась
# же              | же                   | PART       | advmod     | head: Откуда
# взялась         | взяться              | VERB       | ROOT       | head: взялась
# эта             | этот                 | DET        | det        | head: душа
# душа            | душа                 | NOUN       | nsubj      | head: взялась
# у               | у                    | ADP        | case       | head: Елены
# Елены           | елена                | PROPN      | obl        | head: взялась
# ?               | ?                    | PUNCT      | punct      | head: взялась
# Кто             | кто                  | PRON       | nsubj      | head: зажег
# зажег           | зажечь               | VERB       | ROOT       | head: зажег
# этот            | этот                 | DET        | det        | head: огонь
# огонь           | огонь                | NOUN       | obj        | head: зажег
# ?               | ?                    | PUNCT      | punct      | head: зажег
# Вот             | вот                  | PART       | advmod     | head: опять
# опять           | опять                | ADV        | ROOT       | head: опять
# тебе            | тебе                 | PRON       | iobj       | head: опять
# задача          | задача               | NOUN       | nsubj      | head: опять
# ,               | ,                    | PUNCT      | punct      | head: философ
# философ         | философ              | NOUN       | conj       | head: задача
# !               | !                    | PUNCT      | punct      | head: опять
#
# === Именованные сущности ===
# Москвы-реки                    | LOC        | Non-GPE locations, mountain ranges, bodies of water
# Кунцева                        | PER        | Named person or family.
# Андреем Петровичем Берсеневым  | PER        | Named person or family.
# Шубиным                        | PER        | Named person or family.
# Павлом Яковлевичем             | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Какой                          | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Шубин                          | PER        | Named person or family.
# Московского университета       | ORG        | Companies, agencies, institutions, etc.
# Кстати                         | LOC        | Non-GPE locations, mountain ranges, bodies of water
# Шубин                          | PER        | Named person or family.
# Стахова                        | PER        | Named person or family.
# Москве                         | LOC        | Non-GPE locations, mountain ranges, bodies of water
# Августины Христиановны         | PER        | Named person or family.
# Августину Христиановну         | PER        | Named person or family.
# Елены Николаевны               | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Берсенев                       | PER        | Named person or family.
# Николая Артемьевича Стахова    | PER        | Named person or family.
# Анну Васильевну                | PER        | Named person or family.
# Анну Васильевну                | PER        | Named person or family.
# Елены                          | PER        | Named person or family.

# %%
from spacy import displacy

# %%
displacy.render(doc, style="dep", jupyter=True, options={"compact": True, "bg": "#f8f8f8", "color": "#1f77b4", "font": "Arial"})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="ru" id="2e938682a58e4224a7caa3eb2f58ce33-0" class="displacy" width="165650" height="737.0" direction="ltr" style="max-width: none; height: 737.0px; color: #1f77b4; background: #f8f8f8; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">В</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">тени</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">высокой</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">липы,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">берегу</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">Москвы-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">реки,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">недалеко</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">от</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">Кунцева,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">в</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">один</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">из</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">самых</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">жарких</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">летних</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">дней</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">1853</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">года</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">лежали</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">траве</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">два</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">молодых</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">человека.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">Один,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">на</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">вид</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="647.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">лет</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4550">NOUN</

# %%
displacy.render(doc, style="ent", jupyter=True, options={"colors": {"LOC": "linear-gradient(90deg, #aa9cfc, #fc9ce7)", "PER": "#ffcccb"}})
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>В тени высокой липы, на берегу
# <mark class="entity" style="background: linear-gradient(90deg, #aa9cfc, #fc9ce7); padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Москвы-реки
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
# , недалеко от
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Кунцева
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# , в один из самых жарких летних дней 1853 года лежали на траве два молодых человека. Один, на вид лет двадцати трех, высокого роста, черномазый, с острым и немного кривым носом, высоким лбом и сдержанною улыбкой на широких губах, лежал на спине и задумчиво глядел вдаль, слегка прищурив свои небольшие серые глазки; другой лежал на груди, подперев обеими руками кудрявую белокурую голову, и тоже глядел куда-то вдаль. Он был тремя годами старше своего товарища, но казался гораздо моложе; усы его едва пробились и на подбородке вился легкий пух. Было что-то детски-миловидное, что-то привлекательно изящное в мелких чертах его свежего, круглого лица, в его сладких карих глазах, красивых выпуклых губках и белых ручках. Всё в нем дышало счастливою веселостью здоровья, дышало молодостью — беспечностью, самонадеянностью, избалованностью, прелестью молодости. Он и поводил глазами, и улыбался, и подпирал голову, как это делают мальчики, которые знают, что на них охотно заглядываются. На нем было просторное белое пальто вроде блузы; голубой платок охватывал его тонкую шею, измятая соломенная шляпа валялась в траве возле него.<br>В сравнении с ним его товарищ казался стариком, и никто бы не подумал, глядя на его угловатую фигуру, что и он наслаждается, что и ему хорошо. Он лежал неловко; его большая, кверху широкая, книзу заостренная голова неловко сидела на длинной шее; неловкость сказывалась в самом положении его рук, его туловища, плотно охваченного коротким черным сюртучком, его длинных ног с поднятыми коленями, подобных задним ножкам стрекозы. Со всем тем нельзя было не признать в нем хорошо воспитанного человека; отпечаток «порядочности» замечался во всем его неуклюжем существе, и лицо его, некрасивое и даже несколько смешное, выражало привычку мыслить и доброту. Звали его
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Андреем Петровичем Берсеневым
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ; его товарищ, белокурый молодой человек, прозывался
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубиным
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# ,
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Павлом Яковлевичем
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .<br>— Отчего ты не лежишь, как я, на груди? — начал
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . — Так гораздо лучше. Особенно когда поднимешь ноги и стучишь каблуками дружку о дружку — вот так. Трава под носом: надоест глазеть на пейзаж — смотри на какую-нибудь пузатую козявку, как она ползет по былинке, или на муравья, как он суетится. Право, так лучше. А то ты принял теперь какую-то псевдоклассическую позу, ни дать ни взять танцовщица в балете, когда она облокачивается на картонный утес. Ты вспомни, что ты теперь имеешь полное право отдыхать. Шутка сказать: вышел третьим кандидатом! Отдохните, сэр; перестаньте напрягаться, раскиньте свои члены!<br>
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  произнес всю эту речь в нос, полулениво, полушутливо (балованные дети говорят так с друзьями дома, которые привозят им конфекты), и, не дождавшись ответа, продолжал:<br>— Меня больше всего поражает в муравьях, жуках и других господах насекомых их удивительная серьезность; бегают взад и вперед с такими важными физиономиями, точно и их жизнь что-то значит! Помилуйте, человек, царь созданья, существо высшее, на них взирает, а им и дела до него нет; еще, пожалуй, иной комар сядет на нос царю создания и станет употреблять его себе в пищу. Это обидно. А с другой стороны, чем их жизнь хуже нашей жизни? И отчего же им не важничать, если мы позволяем себе важничать? Ну-ка, философ, разреши мне эту задачу! Что ж ты молчишь? А?<br>— Что? — проговорил, встрепенувшись,
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Берсенев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# .<br>— Что! — повторил
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . — Твой друг излагает перед тобою глубокие мысли, а ты его не слушаешь.<br>— Я любовался видом. Посмотри, как эти поля горячо блестят на солнце! (
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Берсенев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  немного пришепетывал.)<br>— Важный пущен колер, — промолвил
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
# . — Одно слово, натура!<br>
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Берсенев
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  покачал головой.<br>— Тебе бы еще больше меня следовало восхищаться всем этим. Это по твоей части: ты артист.<br>— Нет-с; это не по моей части-с, — возразил
# <mark class="entity" style="background: #ffcccb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Шубин
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PER</span>
# </mark>
#  и надел шляпу на затылок. — Я мясник-с; мое дело — мясо, мясо лепить, плечи, ноги, руки, а тут и формы нет, законченности нет, разъехалось во все стороны... Пойди поймай!<br>— Да ведь и тут красота, — заметил
# <mark class="entity" s
